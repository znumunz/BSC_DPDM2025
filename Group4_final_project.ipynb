# %% [markdown]
# <a href="https://colab.research.google.com/github/znumunz/BSC_DPDM2025/blob/main/Group4_final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CANVA : https://www.canva.com/design/DAHD7QeY6AQ/NoYAkGl7-4UdB4CTaOizSQ/view?utm_content=DAHD7QeY6AQ&utm_campaign=designshare&utm_medium=link2&utm_source=uniquelinks&utlId=h80002e3179

# %% [markdown]
# **กลุ่ม 4**
#
# นางสาวกฤตยา นิกรกุล 663020277-7
#
# นางสาวจิตรลดา นิมินรัมย์ 663020278-5
#
# นายรุ่งแสง กองสุข 663020292-1
#
# นางสาวชญาดา ภาษาเวทย์ 663020581-4

# %% [markdown]
# #1 LSTM

# %% [markdown]
# https://drive.google.com/file/d/17o73hTfz__-4WtlngFxFuc8jTuHSrlvB/view?usp=sharing

# %% [markdown]
# #2 HistGradientBoostingRegressor

# %% [markdown]
# https://colab.research.google.com/drive/12XP7l2wdfedJCZTG2zqwaF-n_YHGuAn9

# %% [markdown]
# #3 Gaussian Process Regression (GPR)

# %% [markdown]
# https://colab.research.google.com/drive/1H3sfxYK7dmDMj8UxiSOcfRDy3kyPQirH

# %% [markdown]
# #4 VotingRegressor

# %% [markdown]
# https://colab.research.google.com/drive/1mmI_kOHZFN06NJ5UkRyHT0XM_14WpTcX
